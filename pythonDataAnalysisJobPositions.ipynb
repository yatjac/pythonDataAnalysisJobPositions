# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#q1
sal=pd.read_csv("Eng_salaries-2.csv")
sal.shape
# Out:
# (78, 6)

# %%
#q1
sal.size
# Out:
# 468

# %%
#q2
sal.head(10)
# Out:
#              Rank Discipline  YearsSinceDegree  YearsOfService Gender  Salary
# 0         Manager          B                56              49   Male  186960
# 1         Manager          A                12               6   Male   93000
# 2         Manager          A                23              20   Male  110515
# 3         Manager          A                40              31   Male  131205
# 4         Manager          B                20              18   Male  104800
# 5         Manager          A                20              20   Male  122400
# 6  SeniorEngineer          A                20              17   Male   81285
# 7         Manager          A                18              18   Male  126300
# 8         Manager          A                29              19   Male   94350
# 9         Manager          A                51              51   Male   57800

# %%
#q3
sal.sample(5)
# Out:
#               Rank Discipline  YearsSinceDegree  YearsOfService Gender  Salary
# 11         Manager          B                23              23   Male  134778
# 26         Manager          A                38              19   Male  148750
# 30  SeniorEngineer          B                 9               7   Male  107008
# 20  JuniorEngineer          B                 4               4   Male   92000
# 32         Manager          A                27              19   Male  103275

# %%
#q4
del sal['Discipline']

# %%
#q5
sal.dtypes["Salary"]
# Out:
# dtype('int64')

# %%
#q6
sal.ndim
# Out:
# 2

# %%
#q7
sal = sal.dropna()

# %%
#q7
sal.shape
# Out:
# (78, 5)

# %%
#q7 no rows were dropped

# %%
#q8
sal.describe()
# Out:
#        YearsSinceDegree  YearsOfService         Salary
# count         78.000000       78.000000      78.000000
# mean          19.705128       15.051282  108023.782051
# std           12.498425       12.139768   28293.661022
# min            1.000000        0.000000   57800.000000
# 25%           10.250000        5.250000   88612.500000
# 50%           18.500000       14.500000  104671.000000
# 75%           27.750000       20.750000  126774.750000
# max           56.000000       51.000000  186960.000000

# %%
#q9
sal[['Salary', 'YearsOfService']].agg(['min', 'mean', 'max']).T
# Out:
#                     min           mean       max
# Salary          57800.0  108023.782051  186960.0
# YearsOfService      0.0      15.051282      51.0

# %%
#Q10
sal.loc[10:25,['Rank', 'YearsSinceDegree', 'Salary']]
# Out:
#               Rank  YearsSinceDegree  Salary
# 10         Manager                39  128250
# 11         Manager                23  134778
# 12  JuniorEngineer                 1   88000
# 13         Manager                35  162200
# 14         Manager                25  153750
# 15         Manager                17  150480
# 16  JuniorEngineer                 8   75044
# 17  JuniorEngineer                 4   92000
# 18         Manager                19  107300
# 19         Manager                29  150500
# 20  JuniorEngineer                 4   92000
# 21         Manager                33  103106
# 22  JuniorEngineer                 4   73000
# 23  JuniorEngineer                 2   85000
# 24         Manager                30   91100
# 25         Manager                35   99418

# %%
#q11
plt.figure(figsize=(5,6))
plt.scatter(sal['YearsOfService'], sal['Salary'], color = 'r', label='scatter plot of Years of Service and Salary')
#the longer you work there the more money you make

# %%
#q12
sal_filtered=sal[sal['Salary']<=100000]

# %%
#q12
sal_filtered.shape
# Out:
# (32, 5)

# %%
#q13
sal_filtered.insert(4, "Salary_square", sal_filtered['Salary']**2, True)

# %%
#q13
sal_filtered.shape
# Out:
# (32, 6)

# %%
#q13
sal_filtered.head(10)
# Out:
#               Rank  YearsSinceDegree  YearsOfService Gender  Salary_square  \
# 1          Manager                12               6   Male     8649000000
# 6   SeniorEngineer                20              17   Male     6607251225
# 8          Manager                29              19   Male     8901922500
# 9          Manager                51              51   Male     3340840000
# 12  JuniorEngineer                 1               0   Male     7744000000
# 16  JuniorEngineer                 8               3   Male     5631601936
# 17  JuniorEngineer                 4               0   Male     8464000000
# 20  JuniorEngineer                 4               4   Male     8464000000
# 22  JuniorEngineer                 4               2   Male     5329000000
# 23  JuniorEngineer                 2               0   Male     7225000000
#
#     Salary
# 1    93000
# 6    81285
# 8    94350
# 9    57800
# 12   88000
# 16   75044
# 17   92000
# 20   92000
# 22   73000
# 23   85000

# %%
#q14
sal.sort_values(by=['Salary'], ascending=False)
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 0          Manager                56              49    Male  186960
# 13         Manager                35              33    Male  162200
# 72         Manager                24              15  Female  161101
# 27         Manager                45              43    Male  155865
# 31         Manager                22              21    Male  155750
# ..             ...               ...             ...     ...     ...
# 55  JuniorEngineer                 2               0  Female   72500
# 71  SeniorEngineer                12               9  Female   71065
# 66  JuniorEngineer                 7               6  Female   63100
# 54  SeniorEngineer                25              22  Female   62884
# 9          Manager                51              51    Male   57800
#
# [78 rows x 5 columns]

# %%
#q15
from matplotlib import style
plt.bar(sal['Rank'], sal['YearsSinceDegree'], label='YearsSinceDegree', color = 'g')
plt.bar(sal['Rank'], sal['YearsOfService'], label='YearsOfService', color = 'cyan')
plt.title('YearsSinceDegree vs YearsOfService')
plt.ylabel('Years')
plt.xlabel('Rank')
plt.legend(loc='best')

# %%
#q16
sns.factorplot(x='Gender',y='Salary',kind='box',data=sal)
plt.savefig('Salary_boxplots.jpg')
#males make more money than females and there doesnt seem to be any outliers.
# Out:
# C:\Users\lafoe\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#q17
sal['Gender']=sal['Gender'].map({'Male':1,'Female':0})

# %%
#q17
sal.head(43)
# Out:
#               Rank  YearsSinceDegree  YearsOfService  Gender  Salary
# 0          Manager                56              49       1  186960
# 1          Manager                12               6       1   93000
# 2          Manager                23              20       1  110515
# 3          Manager                40              31       1  131205
# 4          Manager                20              18       1  104800
# 5          Manager                20              20       1  122400
# 6   SeniorEngineer                20              17       1   81285
# 7          Manager                18              18       1  126300
# 8          Manager                29              19       1   94350
# 9          Manager                51              51       1   57800
# 10         Manager                39              33       1  128250
# 11         Manager                23              23       1  134778
# 12  JuniorEngineer                 1               0       1   88000
# ...
